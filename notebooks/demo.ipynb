# %% [markdown]
# # Options Pricing Engine Demo
#
# Welcome to the options pricing engine. This notebook demonstrates how to use the different pricers in the `src/pricers` package.

# %%
from src.pricers.bs import black_scholes

call_price, put_price = black_scholes(S=100, K=100, T=1.0, r=0.05, sigma=0.2)
print(f"Black-Scholes Call: {call_price:.4f}")
